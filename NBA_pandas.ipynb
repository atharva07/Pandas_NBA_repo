# %% [markdown]
# # This is a small Project on Pandas. Here a Database used is a NBA.

# %%
import pandas as pd

# %%
nba = pd.read_csv('nba_all_elo.csv')
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
nba.values
# Out:
# array([[1, '194611010TRH', 'NBA', ..., 'L', 0.64006501, nan],
#        [1, '194611010TRH', 'NBA', ..., 'W', 0.35993499, nan],
#        [2, '194611020CHS', 'NBA', ..., 'W', 0.63110125, nan],
#        ...,
#        [63156, '201506140GSW', 'NBA', ..., 'L', 0.2344346, nan],
#        [63157, '201506170CLE', 'NBA', ..., 'L', 0.48145005, nan],
#        [63157, '201506170CLE', 'NBA', ..., 'W', 0.51854992, nan]],
#       dtype=object)

# %%
nba.dtypes
# Out:
# gameorder          int64
# game_id           object
# lg_id             object
# _iscopy            int64
# year_id            int64
# date_game         object
# seasongame         int64
# is_playoffs        int64
# team_id           object
# fran_id           object
# pts                int64
# elo_i            float64
# elo_n            float64
# win_equiv        float64
# opp_id            object
# opp_fran          object
# opp_pts            int64
# opp_elo_i        float64
# opp_elo_n        float64
# game_location     object
# game_result       object
# forecast         float64
# notes             object
# dtype: object

# %%
nba.shape
# Out:
# (126314, 23)

# %%
nba.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
nba.count()
# Out:
# gameorder        126314
# game_id          126314
# lg_id            126314
# _iscopy          126314
# year_id          126314
# date_game        126314
# seasongame       126314
# is_playoffs      126314
# team_id          126314
# fran_id          126314
# pts              126314
# elo_i            126314
# elo_n            126314
# win_equiv        126314
# opp_id           126314
# opp_fran         126314
# opp_pts          126314
# opp_elo_i        126314
# opp_elo_n        126314
# game_location    126314
# game_result      126314
# forecast         126314
# notes              5424
# dtype: int64

# %%
nba["opp_fran"]
# Out:
# 0            Knicks
# 1           Huskies
# 2            Knicks
# 3             Stags
# 4          Capitols
#             ...
# 126309     Warriors
# 126310    Cavaliers
# 126311     Warriors
# 126312     Warriors
# 126313    Cavaliers
# Name: opp_fran, Length: 126314, dtype: object

# %%
type(nba["opp_fran"])
# Out:
# pandas.core.series.Series

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
nba.insert(3, column = "sport", value = "Basketball")

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id       sport  _iscopy  year_id  date_game  \
# 0          1  194611010TRH   NBA  Basketball        0     1947  11/1/1946
# 1          1  194611010TRH   NBA  Basketball        1     1947  11/1/1946
# 2          2  194611020CHS   NBA  Basketball        0     1947  11/2/1946
# 3          2  194611020CHS   NBA  Basketball        1     1947  11/2/1946
# 4          3  194611020DTF   NBA  Basketball        0     1947  11/2/1946
#
#    seasongame  is_playoffs team_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0           1            0     TRH  ...  40.294830     NYK    Knicks       68
# 1           1            0     NYK  ...  41.705170     TRH   Huskies       66
# 2           1            0     CHS  ...  42.012257     NYK    Knicks       47
# 3           2            0     NYK  ...  40.692783     CHS     Stags       63
# 4           1            0     DTF  ...  38.864048     WSC  Capitols       50
#
# ...

# %%
nba.opp_pts.add(4)
# Out:
# 0          72
# 1          70
# 2          51
# 3          67
# 4          54
#          ...
# 126309    107
# 126310     95
# 126311    108
# 126312    109
# 126313    101
# Name: opp_pts, Length: 126314, dtype: int64

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id       sport  _iscopy  year_id  date_game  \
# 0          1  194611010TRH   NBA  Basketball        0     1947  11/1/1946
# 1          1  194611010TRH   NBA  Basketball        1     1947  11/1/1946
# 2          2  194611020CHS   NBA  Basketball        0     1947  11/2/1946
# 3          2  194611020CHS   NBA  Basketball        1     1947  11/2/1946
# 4          3  194611020DTF   NBA  Basketball        0     1947  11/2/1946
#
#    seasongame  is_playoffs team_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0           1            0     TRH  ...  40.294830     NYK    Knicks       68
# 1           1            0     NYK  ...  41.705170     TRH   Huskies       66
# 2           1            0     CHS  ...  42.012257     NYK    Knicks       47
# 3           2            0     NYK  ...  40.692783     CHS     Stags       63
# 4           1            0     DTF  ...  38.864048     WSC  Capitols       50
#
# ...

# %%
nba["opp_id"].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# TRH      60
# INJ      60
# PIT      60
# DTF      60
# SDS      11
# Name: opp_id, Length: 104, dtype: int64

# %%
nba.tail()
# Out:
#         gameorder       game_id lg_id       sport  _iscopy  year_id  \
# 126309      63155  201506110CLE   NBA  Basketball        0     2015
# 126310      63156  201506140GSW   NBA  Basketball        0     2015
# 126311      63156  201506140GSW   NBA  Basketball        1     2015
# 126312      63157  201506170CLE   NBA  Basketball        0     2015
# 126313      63157  201506170CLE   NBA  Basketball        1     2015
#
#         date_game  seasongame  is_playoffs team_id  ...  win_equiv  opp_id  \
# 126309  6/11/2015         100            1     CLE  ...  60.309792     GSW
# 126310  6/14/2015         102            1     GSW  ...  68.013329     CLE
# 126311  6/14/2015         101            1     CLE  ...  60.010067     GSW
# 126312  6/16/2015         102            1     CLE  ...  59.290245     GSW
# 126313  6/16/2015         103            1     GSW  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location  game_result  \
# ...

# %%
nba.dropna(how = "all")
# Out:
#         gameorder       game_id lg_id       sport  _iscopy  year_id  \
# 0               1  194611010TRH   NBA  Basketball        0     1947
# 1               1  194611010TRH   NBA  Basketball        1     1947
# 2               2  194611020CHS   NBA  Basketball        0     1947
# 3               2  194611020CHS   NBA  Basketball        1     1947
# 4               3  194611020DTF   NBA  Basketball        0     1947
# ...           ...           ...   ...         ...      ...      ...
# 126309      63155  201506110CLE   NBA  Basketball        0     2015
# 126310      63156  201506140GSW   NBA  Basketball        0     2015
# 126311      63156  201506140GSW   NBA  Basketball        1     2015
# 126312      63157  201506170CLE   NBA  Basketball        0     2015
# 126313      63157  201506170CLE   NBA  Basketball        1     2015
#
#         date_game  seasongame  is_playoffs team_id  ...  win_equiv  opp_id  \
# ...

# %%
nba.sort_values("opp_pts", ascending = False)
# Out:
#        gameorder       game_id lg_id       sport  _iscopy  year_id  \
# 50095      25048  198312130DEN   NBA  Basketball        0     1984
# 50094      25048  198312130DEN   NBA  Basketball        1     1984
# 21417      10709  197004120INA   ABA  Basketball        1     1970
# 32880      16441  197502140SDA   ABA  Basketball        1     1975
# 8975        4488  195902270BOS   NBA  Basketball        1     1959
# ...          ...           ...   ...         ...      ...      ...
# 5              3  194611020DTF   NBA  Basketball        1     1947
# 3190        1596  195011220LAL   NBA  Basketball        0     1951
# 3191        1596  195011220LAL   NBA  Basketball        1     1951
# 26684      13343  197210260VIR   ABA  Basketball        1     1973
# 26685      13343  197210260VIR   ABA  Basketball        0     1973
#
#         date_game  seasongame  is_playoffs team_id  ...  win_equiv  opp_id  \
# 50095  12/13/1983          23            0     DEN  ...  41.486488     DET
# ...
